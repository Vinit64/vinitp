# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# dividing the dataset in independent and dependent values
X=df.iloc[:,3:13]
Y=df.iloc[:,13:14]
# Out:
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
#checking the types of datatypes in the categorical variables
groupdata1=df.groupby(by="IsActiveMember").size()
print(groupdata1)
groupdata2=df.groupby(by="Gender").size()
print(groupdata2)
# Out:
# IsActiveMember
# 0    4849
# 1    5151
# dtype: int64
# Gender
# Female    4543
# Male      5457
# dtype: int64

# %%
#encoding the categorical variables
geography=pd.get_dummies(X["Geography"],drop_first = True)
gender=pd.get_dummies(X["Gender"],drop_first = True)
X=X.drop(['Geography','Gender'],axis=1)

# %%
#splitting the dataset in the test and train
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
#feature scalling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#adding the newly two created columns(gender and geography)
X=pd.concat([X,geography,gender],axis=1)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_61640\962641680.py in <module>
# ----> 1 X_train.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
# import the keras library
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

# %%
#intialsing the ANN
classifier=Sequential()

# %%
#adding the input layer and that is Relu
classifier.add(Dense(units = 6,kernel_initializer='he_uniform',activation='relu',input_dim=11))
#adding the hidden layer thai is relu
classifier.add(Dense(units = 6,kernel_initializer='he_uniform',activation='relu'))
#adding the output layer
classifier.add(Dense(units = 1,kernel_initializer='glorot_uniform',activation='sigmoid'))
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 6)                 42
#
#  dense_3 (Dense)             (None, 6)                 42
#
#  dense_4 (Dense)             (None, 6)                 42
#
#  dense_5 (Dense)             (None, 6)                 42
#
#  dense_6 (Dense)             (None, 6)                 42
#
#  dense_7 (Dense)             (None, 1)                 7
#
#  dense_8 (Dense)             (None, 6)                 12
#
#  dense_9 (Dense)             (None, 6)                 42
#
#  dense_10 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 392
# Trainable params: 392
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#fitting the ANN to the training set
model_history=classifier.fit(X_train,Y_train,validation_split=0.33,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 2/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 3/100
# 536/536 [==============================] - 1s 957us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 4/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 5/100
# 536/536 [==============================] - 1s 966us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 6/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 7/100
# 536/536 [==============================] - 1s 997us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 8/100
# 536/536 [==============================] - 1s 998us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 9/100
# 536/536 [==============================] - 1s 953us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 10/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 11/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 12/100
# 536/536 [==============================] - 1s 944us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 13/100
# 536/536 [==============================] - 1s 984us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 14/100
# 536/536 [==============================] - 1s 986us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 15/100
# 536/536 [==============================] - 1s 999us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 16/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 17/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 18/100
# 536/536 [==============================] - 1s 978us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 19/100
# 536/536 [==============================] - 1s 961us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 20/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 21/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 22/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 23/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 24/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 25/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 26/100
# 536/536 [==============================] - 1s 947us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 27/100
# 536/536 [==============================] - 1s 992us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 28/100
# 536/536 [==============================] - 1s 992us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 29/100
# 536/536 [==============================] - 1s 997us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 30/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 31/100
# 536/536 [==============================] - 1s 976us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 32/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 33/100
# 536/536 [==============================] - 1s 971us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 34/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 35/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 36/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 37/100
# 536/536 [==============================] - 1s 991us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 38/100
# 536/536 [==============================] - 1s 998us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 39/100
# 536/536 [==============================] - 1s 978us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 40/100
# 536/536 [==============================] - 1s 954us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 41/100
# 536/536 [==============================] - 1s 981us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 42/100
# 536/536 [==============================] - 1s 971us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 43/100
# 536/536 [==============================] - 1s 994us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 44/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 45/100
# 536/536 [==============================] - 1s 992us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 46/100
# 536/536 [==============================] - 1s 988us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 47/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 48/100
# 536/536 [==============================] - 1s 986us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 49/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 50/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 51/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 52/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 53/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 54/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 55/100
# 536/536 [==============================] - 1s 995us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 56/100
# 536/536 [==============================] - 1s 932us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 57/100
# 536/536 [==============================] - 1s 980us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 58/100
# 536/536 [==============================] - 1s 938us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 59/100
# 536/536 [==============================] - 1s 935us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 60/100
# 536/536 [==============================] - 1s 973us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 61/100
# 536/536 [==============================] - 1s 956us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 62/100
# 536/536 [==============================] - 1s 966us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 63/100
# 536/536 [==============================] - 0s 926us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 64/100
# 536/536 [==============================] - 1s 939us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 65/100
# 536/536 [==============================] - 1s 979us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 66/100
# 536/536 [==============================] - 1s 957us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 67/100
# 536/536 [==============================] - 1s 970us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 68/100
# 536/536 [==============================] - 1s 957us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 69/100
# 536/536 [==============================] - 0s 923us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 70/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 71/100
# 536/536 [==============================] - 1s 953us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 72/100
# 536/536 [==============================] - 1s 957us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 73/100
# 536/536 [==============================] - 1s 958us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 74/100
# 536/536 [==============================] - 1s 962us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 75/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 76/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 77/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 78/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 79/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 80/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 81/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 82/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 83/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 84/100
# 536/536 [==============================] - 1s 940us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 85/100
# 536/536 [==============================] - 0s 925us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 86/100
# 536/536 [==============================] - 0s 899us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 87/100
# 536/536 [==============================] - 0s 898us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 88/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 89/100
# 536/536 [==============================] - 0s 913us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 90/100
# 536/536 [==============================] - 1s 1ms/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 91/100
# 536/536 [==============================] - 0s 920us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 92/100
# 536/536 [==============================] - 1s 988us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 93/100
# 536/536 [==============================] - 0s 893us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 94/100
# 536/536 [==============================] - 1s 979us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 95/100
# 536/536 [==============================] - 1s 961us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 96/100
# 536/536 [==============================] - 0s 904us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 97/100
# 536/536 [==============================] - 1s 938us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 98/100
# 536/536 [==============================] - 0s 905us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 99/100
# 536/536 [==============================] - 1s 939us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988
# Epoch 100/100
# 536/536 [==============================] - 1s 936us/step - loss: 3.5943 - accuracy: 0.1041 - val_loss: 3.6260 - val_accuracy: 0.0988

# %%
#checking the acciracy
y_pred=classifier.predict(X_test)
for i in y_pred:
    if i>0.5:
        i=1
    else:
        i=0
print(y_pred)
# Out:
# 63/63 [==============================] - 0s 563us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_61640\2493184547.py in <module>
#       2 y_pred=classifier.predict(X_test)
#       3 for i in y_pred:
# ----> 4     if i>0.5:
#       5         i=1
#       6     else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#confusino matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_61640\699207506.py in <module>
#       1 #confusino matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 cm=confusion_matrix(Y_test,y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ValueError: Classification metrics can't handle a mix of binary and multilabel-indicator targets
